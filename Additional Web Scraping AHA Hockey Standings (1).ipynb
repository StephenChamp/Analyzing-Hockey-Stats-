# %% [markdown]
# # Additional Web Scraping AHA Hockey Standings

# %% [markdown]
# Taking my intial webscraping a little further we can further scrape the AHA website. There is a bunch of player related data we can scrape on players. This would be a great dataset to analyze players.

# %% [markdown]
# ### Import packages needed to Web Scrape, I will be using Beautiful Soup

# %%
import pandas as pd
import urllib.request
from bs4 import BeautifulSoup
import re

# %% [markdown]
# ### We choose the website we want to look at and specifically the current league I play in

# %%
website ="https://www.ahahockey.com/standings/twin-cities?selected_tier=316"

# %% [markdown]
# ### Download the HTML code and start a BeautifulSoup Object

# %%
response = urllib.request.urlopen(website)
the_website = response.read()
soup = BeautifulSoup(the_website, "html.parser")

# %% [markdown]
# ### Here we find all of the links on this page

# %%
links = []
for link in soup.find_all('a'):
    links.append(link.get('href'))

# %% [markdown]
# ### If we go to the individual team pages they have data on all of the players on each team. Lets go to each page and download the player stats for each team as well. We will need to start by getting the link to each of these pages.

# %%
team_links = []
for x in links:
    if x is None:
        print('skip')
    elif re.search('team_results', x):
            team_links.append(x)
# Out:
# skip

# %% [markdown]
# ### We are able to locate all of the teams home page with player stats

# %%
team_links
# Out:
# ['/team_results/river-pirates/75/2035',
#  '/team_results/barons-b3/401/2028',
#  '/team_results/battle-cats/67/2029',
#  '/team_results/fighting-loons-b3/739/2030',
#  '/team_results/fighting-piranhas-b3/56/2031',
#  '/team_results/rack-attack-b3/47/2034',
#  '/team_results/venom-b3/59/2037',
#  '/team_results/spitfires-b3/395/2036',
#  '/team_results/nothern-horde-b3/32/2033',
#  '/team_results/monster-squad/740/2032']

# %% [markdown]
# ### Lets do some cleaning on the team name to make it easier to read for our data

# %%
actual_name = []
for x in team_links:
    actual_name.append(x.split('/')[2])
actual_name
# Out:
# ['river-pirates',
#  'barons-b3',
#  'battle-cats',
#  'fighting-loons-b3',
#  'fighting-piranhas-b3',
#  'rack-attack-b3',
#  'venom-b3',
#  'spitfires-b3',
#  'nothern-horde-b3',
#  'monster-squad']

# %% [markdown]
# ### Now that we have all of the links to the individual teams we can go to each of these pages. At each page we will scrape the player specific data and put it into a dataframe.

# %%
Play_for = []
name = []
GP = []
Goals = []
Assists = []
Points = []
SHG = []
PPG = []
PIM = []
team_counter = 0

for team in team_links:
    table_counter = 1
    counter = 1
    website ="https://www.ahahockey.com" + team
    response = urllib.request.urlopen(website)
    the_website = response.read()
    soup = BeautifulSoup(the_website, "html.parser")
    tables = soup.find_all('table')
    for table in tables:
        for x in table.find_all('td'):      
            if table_counter > 1:
                counter = 100
            if counter == 1:
                name.append(x.get_text().strip())
                Play_for.append(actual_name[team_counter])
                counter += 1
            elif counter == 2:
                GP.append(x.get_text().strip())
                counter += 1
            elif counter == 3:
                Goals.append(x.get_text().strip())
                counter += 1
            elif counter == 4:
                Assists.append(x.get_text().strip())
                counter += 1
            elif counter == 5:
                Points.append(x.get_text().strip())
                counter += 1
            elif counter == 6:
                SHG.append(x.get_text().strip())
                counter += 1
            elif counter == 7:
                PPG.append(x.get_text().strip())
                counter += 1
            elif counter == 8:
                PIM.append(x.get_text().strip())
                counter = 1
        table_counter += 1
    team_counter +=1

# %% [markdown]
# ### Turn our Lists into a pandas DataFrame

# %%
Hockey_data = pd.DataFrame([Play_for, name, GP, Goals, Assists, Points, SHG, PPG, PIM])
Hockey_data = Hockey_data.transpose()
Hockey_data.columns = ['Play_for', 'name', 'GP', 'Goals', 'Assists', 'Points', 'SHG', 'PPG', 'PIM']
Hockey_data
# Out:
#              Play_for                 name  GP Goals Assists Points SHG PPG  \
# 0       river-pirates          #3. J.  Lee  17     3       8     11   1   0
# 1       river-pirates       #4. E.  Sureda  16    11      11     22   0   1
# 2       river-pirates      #5. P.  Rudolph  13     3       3      6   0   1
# 3       river-pirates     #6. B.  Herdegen  17     3       2      5   0   0
# 4       river-pirates   #7. J.  Leiviska C  15    11       9     20   1   0
# 5       river-pirates       #8. J.  Drewes  15     6       6     12   0   2
# 6       river-pirates       #9. J.  Dayton  14     6       9     15   0   0
# 7       river-pirates     #11. M.  Gansmoe  15     4       7     11   0   0
# 8       river-pirates     #12. N.  Cornell  15     8       4     12   1   1
# 9       river-pirates     #16. R.  Collins  17     3       7     10   0   0
# 10      river-pirates       #17. P.  Woods   7     3       5      8   0   0
# 11      river-pirates    #20. J.  Villella  14     5       5     10   0   0
# 12      river-pirates        #21. J.  Gort   2     0       0      0   0   0
# 13      river-pirates    #22. R.  Villella  17     4       4      8   0   1
# 14      river-pirates       #28. D.  Knoll  17    21      14     35   0   3
# 15      river-pirates      #38. F.  Gordon   6     0       6      6   0   0
# 16      river-pirates         #42. P.  Ang  12     6       7     13   0   0
# 17      river-pirates    #44. S.  Peterson  17    11      14     25   0   0
# 18      river-pirates       #77. M.  Neimy   6     0       0      0   0   0
# 19      river-pirates    #89. B.  Thompson  15     0       2      2   0   0
# 20          barons-b3     #2. D.  Sundberg   6     1       2      3   0   0
# 21          barons-b3     #6. J.  Anderson  14     8      10     18   0   2
# 22          barons-b3        #8. H.  Loven  15     2       1      3   0   0
# 23          barons-b3  #9. J.  Henderson C  15     5       7     12   0   1
# 24          barons-b3     #10. B.  Lentsch  15     5       8     13   0   2
# 25          barons-b3     #11. D.  Garrett  15     2       6      8   0   0
# 26          barons-b3      #14. E.  Loomis  15     1       3      4   0   0
# 27          barons-b3       #17. R.  Hanke  11     6       7     13   0   1
# 28          barons-b3      #18. B.  Hanson  16     2      11     13   0   0
# 29          barons-b3     #20. E.  Cornett   5     0       3      3   0   0
# ..                ...                  ...  ..   ...     ...    ...  ..  ..
# 170  nothern-horde-b3      #38. M.  Leslie  10     2       3      5   0   1
# 171  nothern-horde-b3    #40. D.  McDonald  12     3       4      7   0   1
# 172  nothern-horde-b3       #46. B.  Flick   9     0       6      6   0   0
# 173  nothern-horde-b3      #66. R.  Larson  14     1       5      6   0   0
# 174  nothern-horde-b3        #74. J.  Vogt  11     2       3      5   0   0
# 175  nothern-horde-b3      #77. J.  Cleath   9     2       2      4   0   0
# 176  nothern-horde-b3        #79. T.  Rand   8     2       3      5   0   0
# 177  nothern-horde-b3     #80. T.  Lofgren   8     1       3      4   0   0
# 178  nothern-horde-b3     #84. C.  Warlick  13    12      14     26   0   1
# 179  nothern-horde-b3   #88. D.  Wiplinger  15     3       3      6   0   0
# 180     monster-squad    #00. C.  Maggiolo   9     0       0      0   0   0
# 181     monster-squad        #4. J.  Klose  16     3       6      9   0   2
# 182     monster-squad       #5. R.  Miller  15     0       0      0   0   0
# 183     monster-squad      #6. E.  Pletsch   9     5       4      9   0   1
# 184     monster-squad    #7. J.  Thunstrom   4     0       2      2   0   0
# 185     monster-squad        #9. A.  Juran   0     0       0      0   0   0
# 186     monster-squad    #10. T.  Newstrom  13     1       5      6   0   0
# 187     monster-squad  #11. D.  Dombrovski   2     0       1      1   0   0
# 188     monster-squad     #12. J.  Johnson  15     1       3      4   0   0
# 189     monster-squad     #17. M.  Mussell  13     9       7     16   0   1
# 190     monster-squad     #18. C.  Edwards  11     0       0      0   0   0
# 191     monster-squad  #19. R.  Desvousges   5     0       2      2   0   0
# 192     monster-squad      #22. R.  Vesall  17     2       2      4   0   1
# 193     monster-squad      #25. J.  Romain  10     4       2      6   0   0
# 194     monster-squad       #27. J.  Girtz   1     0       1      1   0   0
# 195     monster-squad    #29. J.  Maggiolo  17     4       4      8   0   0
# 196     monster-squad  #31. M.  Maggiolo C  10     1       3      4   0   0
# 197     monster-squad    #32. A.  Buechner  14     5       4      9   0   0
# 198     monster-squad        #77. M.  Spah   9     0       0      0   0   0
# 199     monster-squad      #97. B.  Vesall  17     2       6      8   0   0
#
#     PIM
# 0    22
# 1     6
# 2     8
# 3     2
# 4    16
# 5     0
# 6     8
# 7     6
# 8     2
# 9     0
# 10    2
# 11    4
# 12    0
# 13   18
# 14   20
# 15    0
# 16    6
# 17    8
# 18    0
# 19    2
# 20    4
# 21    4
# 22   16
# 23    4
# 24    4
# 25    8
# 26    6
# 27   10
# 28    2
# 29    2
# ..   ..
# 170   2
# 171   0
# 172   4
# 173   4
# 174   2
# 175   8
# 176  16
# 177   2
# 178   4
# 179  16
# 180  15
# 181   4
# 182   6
# 183   6
# 184  12
# 185   0
# 186  32
# 187   0
# 188  10
# 189   2
# 190   2
# 191   2
# 192   2
# 193   4
# 194   0
# 195   2
# 196   2
# 197   8
# 198   2
# 199   8
#
# [200 rows x 9 columns]

# %% [markdown]
# ### With more indepth data around teams, scoring, and potential we can further analyze this data to understand certain categories of players
